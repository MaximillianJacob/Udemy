# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
import feature_engine

# %%
#Lazy loading behaviour
dir(feature_engine)
# Out:
# ['PACKAGE_ROOT',
#  'VERSION_PATH',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_base_transformers',
#  '_check_init_parameters',
#  '_docstrings',
#  'dataframe_checks',
#  'discretisation',
#  'encoding',
#  'feature_engine',
#  'name',
#  'pathlib',
#  'tags',
#  'variable_handling',
#  'version_file']

# %%
from feature_engine.encoding import (
    RareLabelEncoder, 
    OrdinalEncoder, 
    OneHotEncoder,
)

# %%
import feature_engine.encoding

# %%
dir(feature_engine.encoding)
# Out:
# ['CountFrequencyEncoder',
#  'DecisionTreeEncoder',
#  'MeanEncoder',
#  'OneHotEncoder',
#  'OrdinalEncoder',
#  'RareLabelEncoder',
#  'StringSimilarityEncoder',
#  'WoEEncoder',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_helper_functions',
#  'base_encoder',
#  'count_frequency',
#  'decision_tree',
#  'mean_encoding',
#  'one_hot',
#  'ordinal',
#  'rare_label',
#  'similarity_encoder',
#  'woe']

# %%
dir(feature_engine)
# Out:
# ['PACKAGE_ROOT',
#  'VERSION_PATH',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_base_transformers',
#  '_check_init_parameters',
#  '_docstrings',
#  'dataframe_checks',
#  'discretisation',
#  'encoding',
#  'feature_engine',
#  'name',
#  'pathlib',
#  'tags',
#  'variable_handling',
#  'version_file']

# %%
import pkgutil

# %%
for module in pkgutil.iter_modules(feature_engine.__path__):
    print(module)
# Out:
# ModuleInfo(module_finder=FileFinder('/home/max/Udemy/Udemy/machine_learning_imbalanced_data/.venv/lib/python3.10/site-packages/feature_engine'), name='_base_transformers', ispkg=True)
# ModuleInfo(module_finder=FileFinder('/home/max/Udemy/Udemy/machine_learning_imbalanced_data/.venv/lib/python3.10/site-packages/feature_engine'), name='_check_init_parameters', ispkg=True)
# ModuleInfo(module_finder=FileFinder('/home/max/Udemy/Udemy/machine_learning_imbalanced_data/.venv/lib/python3.10/site-packages/feature_engine'), name='_docstrings', ispkg=True)
# ModuleInfo(module_finder=FileFinder('/home/max/Udemy/Udemy/machine_learning_imbalanced_data/.venv/lib/python3.10/site-packages/feature_engine'), name='_prediction', ispkg=True)
# ModuleInfo(module_finder=FileFinder('/home/max/Udemy/Udemy/machine_learning_imbalanced_data/.venv/lib/python3.10/site-packages/feature_engine'), name='creation', ispkg=True)
# ...

# %%
for module in pkgutil.iter_modules(feature_engine.__path__):
    print(module.name)
# Out:
# _base_transformers
# _check_init_parameters
# _docstrings
# _prediction
# creation
# dataframe_checks
# datasets
# datetime
# discretisation
# encoding
# imputation
# outliers
# pipeline
# preprocessing
# scaling
# selection
# tags
# timeseries
# transformation
# variable_handling
# wrappers

# %%
from feature_engine import imputation

# %%
dir(imputation)
# Out:
# ['AddMissingIndicator',
#  'ArbitraryNumberImputer',
#  'CategoricalImputer',
#  'DropMissingData',
#  'EndTailImputer',
#  'MeanMedianImputer',
#  'RandomSampleImputer',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'arbitrary_number',
#  'base_imputer',
#  'categorical',
#  'drop_missing_data',
#  'end_tail',
#  'mean_median',
#  'missing_indicator',
#  'random_sample']

# %%
[print(item+',')for item in dir(feature_engine.imputation) if 'arbitra' in item.lower() or 'imputer' in item.lower() or 'indicator' in item.lower()]
# Out:
# AddMissingIndicator,
# ArbitraryNumberImputer,
# CategoricalImputer,
# EndTailImputer,
# MeanMedianImputer,
# RandomSampleImputer,
# arbitrary_number,
# base_imputer,
# missing_indicator,
# [None, None, None, None, None, None, None, None, None]

# %%
from feature_engine.imputation import(
    AddMissingIndicator,
ArbitraryNumberImputer,
CategoricalImputer,
MeanMedianImputer,
)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import (
    train_test_split,
    TunedThresholdClassifierCV
)

# %%
import sklearn.model_selection

# %%
[item for item in dir(sklearn.model_selection) if 'threshold' in item.lower()]
# Out:
# ['FixedThresholdClassifier',
#  'TunedThresholdClassifierCV',
#  '_classification_threshold']

# %%
from sklearn.pipeline import Pipeline

from sklearn.metrics import (
    balanced_accuracy_score,
    PrecisionRecallDisplay,
    RocCurveDisplay
)

# %%
from xgboost import XGBClassifier

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading the data

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers.readers:
#
# ...

# %%
test = pd.read_csv('../loan_data.csv')
dir(test)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__arrow_c_stream__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__dataframe_consortium_standard__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
# ...

# %%
test.dtypes
# Out:
# new_customer                         int64
# income_verification                 object
# language                            object
# age                                  int64
# gender                              object
# country                             object
# amount                             float64
# loan_duration                        int64
# use_of_loan                         object
# education                           object
# marital_status                      object
# nr_dependants                      float64
# employment_status                   object
# employment_duration                 object
# work_experience                     object
# occupation                          object
# home_ownership                      object
# income                             float64
# existing_debt                        int64
# total_debt                         float64
# debt_to_income                     float64
# disposable_income                  float64
# ...

# %%
df = pd.read_csv('../loan_data.csv', low_memory=False)
df.head()
# Out:
#    new_customer income_verification  language  age  gender country    amount  \
# 0             0   expenses_verified  estonian   23    male      EE 5500.0000
# 1             0   expenses_verified   russian   25    male      EE 1200.0000
# 2             1            verified   finnish   28    male      FI 2000.0000
# 3             1          unverified   finnish   49  female      FI 1000.0000
# 4             0   expenses_verified  estonian   25  female      EE 4100.0000
#
#    loan_duration         use_of_loan   education marital_status  \
# 0             60  loan_consolidation   secondary         single
# 1             60               other  vocational         single
# 2             60               other      higher     cohabitant
# 3             60               other       basic        married
# 4             60  loan_consolidation   secondary     cohabitant
#
#    nr_dependants employment_status employment_duration work_experience  \
# ...

# %%
test.dtypes == df.dtypes
# Out:
# new_customer                       True
# income_verification                True
# language                           True
# age                                True
# gender                             True
# country                            True
# amount                             True
# loan_duration                      True
# use_of_loan                        True
# education                          True
# marital_status                     True
# nr_dependants                      True
# employment_status                  True
# employment_duration                True
# work_experience                    True
# occupation                         True
# home_ownership                     True
# income                             True
# existing_debt                      True
# total_debt                         True
# debt_to_income                     True
# disposable_income                  True
# credit_score_microL                True
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df.drop('default', axis=1),
    df.default,
    test_size=0.1,
    random_state=10
)

X_train.shape, X_test.shape
# Out:
# ((90589, 31), (10066, 31))

# %%
y_train.mean(), y_test.mean()
# Out:
# (np.float64(0.1002881144509819), np.float64(0.09944367176634214))
