# %%
import tkinter as tk

# %%
import tkinter as tk
from tkinter import ttk

# %%
dir(ttk)
# Out:
# ['Button',
#  'Checkbutton',
#  'Combobox',
#  'Entry',
#  'Frame',
#  'Label',
#  'LabelFrame',
#  'LabeledScale',
#  'Labelframe',
#  'Menubutton',
#  'Notebook',
#  'OptionMenu',
#  'PanedWindow',
#  'Panedwindow',
#  'Progressbar',
#  'Radiobutton',
#  'Scale',
#  'Scrollbar',
#  'Separator',
#  'Sizegrip',
#  'Spinbox',
#  'Style',
#  'Treeview',
#  'Widget',
#  '_REQUIRE_TILE',
#  '__all__',
#  '__author__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '__version__',
#  '_convert_stringval',
#  '_flatten',
#  '_format_elemcreate',
#  '_format_layoutlist',
#  '_format_mapdict',
#  '_format_optdict',
#  '_format_optvalue',
#  '_join',
#  '_list_from_layouttuple',
#  '_list_from_statespec',
#  '_load_tile',
#  '_mapdict_values',
#  '_script_from_settings',
#  '_splitdict',
#  '_stringify',
#  '_tclobj_to_py',
#  '_to_number',
#  '_val_or_dict',
#  'setup_master',
#  'tclobjs_to_py',
# ...

# %%
import tkinter as tk
from tkinter import ttk

def greet():
    print("Hello, world!")

root = tk.Tk() 

greet_button = ttk.Button(root, text='Greet', command=greet, padding=(30,40)).pack(side = 'left', fill='x')
quit_button = ttk.Button(root, text='Quit', command=root.destroy, padding = (10,50)).pack(fill='x', expand=True)


root.mainloop()

# %%
dir(root)
# Out:
# ['_Misc__winfo_getint',
#  '_Misc__winfo_parseitem',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_bind',
#  '_configure',
#  '_displayof',
#  '_getboolean',
#  '_getconfigure',
#  '_getconfigure1',
#  '_getdoubles',
#  '_getints',
#  '_grid_configure',
#  '_gridconvvalue',
#  '_last_child_ids',
#  '_loadtk',
#  '_nametowidget',
#  '_noarg_',
#  '_options',
#  '_register',
#  '_report_exception',
#  '_root',
#  '_subst_format',
#  '_subst_format_str',
#  '_substitute',
#  '_tclCommands',
#  '_tkloaded',
#  '_w',
#  '_windowingsystem',
#  'after',
# ...

# %%
import tkinter as tk
from tkinter import ttk 

def greet():
    print(f"Hello {user_name.get() or 'World'}")

root = tk.Tk() 
root.geometry("600x400")

yes_box = tk.Label(root, text='YES', bg='green', fg='white').pack(side='top', ipadx=40)
no_box = tk.Label(root, text='NO', bg='red', fg='white').pack(side='top', ipadx=43)

user_name = tk.StringVar()

name_label = ttk.Label(root, text='Name: ').pack(side='left', padx=(0,10))

name_entry = ttk.Entry(root, width=15, textvariable=user_name)
name_entry.pack(side='left')
name_entry.focus()

greet_button = ttk.Button(root, text='Greet').pack(side='left')
quit_button = ttk.Button(root, text='Quit', command = root.destroy).pack(side='right')

root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk 
from windows import set_dpi_awareness 
from PIL import Image, ImageTk


set_dpi_awareness()

root = tk.Tk()
root.geometry("600x400")

root.title('Widget Examples')

image = Image.open("splash.png").resize((64,64))
photo = ImageTk.PhotoImage(image)

label = ttk.Label(root, text="Image with text", image=photo, padding=5, compound='right')
label.pack()


root.mainloop()

# %%
def set_dpi_awareness():
    try:
        from ctypes import windll
        windll.shcore.SetProcessDpiAwareness(1)
    except:
        pass

# %%
def set_dpi_awareness():
    try:
        from ctypes import windll
        windll.shcore.SetProcessDpiAwareness(1)
    except:
        pass

# %%
import tkinter as tk
from tkinter import ttk
from windows import set_dpi_awareness
from PIL import Image, ImageTk 

def set_dpi_awareness():
    try:
        from ctypes import windll
        windll.shcore.SetProcessDpiAwareness(1)
    except:
        pass


root = tk.Tk()
root.geometry("600x400")


image = Image.open("splash.png").resize((100,100))
photo = ImageTk.PhotoImage(image)

label = ttk.Label(root, text="Image with text", image=photo, padding=5, compound='right')
label.pack()

root.mainloop()

# %%
# import tkinter as tk
# from tkinter import ttk
# from PIL import Image, ImageTk

import tkinter as tk
from tkinter import ttk
from windows import set_dpi_awareness
from PIL import Image, ImageTk 

def set_dpi_awareness():
    try:
        from ctypes import windll
        windll.shcore.SetProcessDpiAwareness(1)
    except:
        pass

root = tk.Tk()
root.geometry("600x400")

# image = Image.open("splash.png").resize((100,100))
# photo = ImageTk.PhotoImage(image)
image = Image.open("splash.png").resize((100,100))
photo = ImageTk.PhotoImage(image)

# label = ttk.Label(root, text="Image with text", image=photo, padding=5, compound='right')
# label.pack()
label = ttk.Label(root, text="Image with text", image=photo, padding=5, compound='right')
label.pack()

root.mainloop()

# %%
import tkinter as tk 
from tkinter import ttk 
from PIL import Image, ImageTk

def set_dpi_awareness():
    try:
        from ctypes import windll
        windll.shcore.SetProcessDpiAwareness(1)
    except:
        pass

set_dpi_awareness()

root = tk.Tk()
root.geometry("600x400")

root.title("widget examples")

greeting=tk.StringVar()

label = ttk.Label(root, padding=10, textvariable=greeting)
label.pack()

greeting.set("Hello, John!")

root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk
from PIL import Image, ImageTk

def set_dpi_awareness():
    try:
        from ctypes import windll
        windll.shcore.SetProcessDpiAwareness(1)
    except:
        pass

set_dpi_awareness()

root = tk.Tk()
root.geometry("600x400")

root.title("Widge examples")

greeting=tk.StringVar()

label = ttk.Label(root, padding=10, textvariable=greeting)
label.pack()

greeting.set("Hello, John1")
root.mainloop()

# %%
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[5], line 11
#       8 image = Image.open("splash.png")
#       9 photo = ImageTk.PhotoImage(image)
# ---> 11 label = ttk.Label(root, image=photo, padding=5)
#      12 label.pack()
#      15 root.mainloop()
#
# File ~/anaconda3/lib/python3.10/tkinter/ttk.py:754, in Label.__init__(self, master, **kw)
#     741 def __init__(self, master=None, **kw):
#     742     """Construct a Ttk Label with parent master.
#     743
#     744     STANDARD OPTIONS
#    (...)
#     752         relief, text, wraplength
#     753     """
# --> 754     Widget.__init__(self, master, "ttk::label", kw)
#
# File ~/anaconda3/lib/python3.10/tkinter/ttk.py:552, in Widget.__init__(self, master, widgetname, kw)
#     549 if not getattr(master, '_tile_loaded', False):
#     550     # Load tile now, if needed
#     551     _load_tile(master)
# ...
